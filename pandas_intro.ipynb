# %% [markdown]
# # Let's Use Pandas!

# %% [markdown]
# First, import pandas.

# %%
import pandas as pd

# %% [markdown]
# Now read in the heart dataset.

# %%
heart = pd.read_csv('heart.csv')

# %% [markdown]
# What does .head( ) do? What do you learn about the dataset by using it here?

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# What about .tail( )? What about .info( ) and .describe( )?

# %%
heart.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB

# %%
heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# target is usually used with scikit-learn and is supposed to be used for predictions

# %% [markdown]
# With pandas, strings will be returned as objects

# %% [markdown]
# ### What can we figure out / guess about the different columns?

# %% [markdown]
# Here's a row that our engineer accidentally left out of the .csv file, expressed as a Python dictionary:

# %%
extra_rows = {'age': [40, 30], 'sex': [1, 0], 'cp': [0, 0], 'trestbps': [120, 130], 'chol': [240, 200],
             'fbs': [0, 0], 'restecg': [1, 0], 'thalach': [120, 122], 'exang': [0, 1],
              'oldpeak': [0.1, 1.0], 'slope': [1, 1], 'ca': [0, 1], 'thal': [2, 3], 'target': [0, 0]}
extra_rows
# Out:
# {'age': [40, 30],
#  'sex': [1, 0],
#  'cp': [0, 0],
#  'trestbps': [120, 130],
#  'chol': [240, 200],
#  'fbs': [0, 0],
#  'restecg': [1, 0],
#  'thalach': [120, 122],
#  'exang': [0, 1],
#  'oldpeak': [0.1, 1.0],
#  'slope': [1, 1],
#  'ca': [0, 1],
#  'thal': [2, 3],
#  'target': [0, 0]}

# %% [markdown]
# How can we add this to the bottom of our dataset?

# %%
e_rows = pd.DataFrame(extra_rows)
heart = heart.append(e_rows, ignore_index=True)
heart.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
# 303   40    1   0       120   240    0        1      120      0      0.1
# 304   30    0   0       130   200    0        0      122      1      1.0
#
#      slope  ca  thal  target
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
# 303      1   0     2       0
# 304      1   1     3       0

# %% [markdown]
# How many different values does have slope have? What about sex? And target?

# %%
heart['slope'].value_counts()
# Out:
# 2    142
# 1    142
# 0     21
# Name: slope, dtype: int64

# %%
heart['sex'].value_counts()
# Out:
# 1    208
# 0     97
# Name: sex, dtype: int64

# %%
heart['target'].value_counts()
# Out:
# 1    165
# 0    140
# Name: target, dtype: int64

# %% [markdown]
# Let's add a new column to our dataset called "test". Set all of its values to 0.

# %%
heart['test'] = 0
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  test
# 0   0     1       1     0
# 1   0     2       1     0
# 2   0     2       1     0
# 3   0     2       1     0
# 4   0     2       1     0

# %% [markdown]
# ## Filtering

# %% [markdown]
# We can use filtering techniques to see only certain rows of our data. If we wanted to see only the rows for patients 70 years of age or older, we can simply type:

# %%
heart[heart['age'] >= 70]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 25    71    0   1       160   302    0        1      162      0      0.4
# 60    71    0   2       110   265    1        0      130      0      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 145   70    1   1       156   245    0        0      143      0      0.0
# 151   71    0   0       112   149    0        1      125      0      1.6
# 225   70    1   0       145   174    0        1      125      1      2.6
# 234   70    1   0       130   322    0        0      109      0      2.4
# 238   77    1   0       125   304    0        0      162      1      0.0
# 240   70    1   2       160   269    0        1      112      1      2.9
#
#      slope  ca  thal  target  test
# 25       2   2     2       1     0
# 60       2   1     2       1     0
# 129      2   1     2       1     0
# 144      1   0     2       1     0
# 145      2   0     2       1     0
# 151      1   0     2       1     0
# 225      0   0     3       0     0
# 234      1   3     2       0     0
# 238      2   3     2       0     0
# 240      1   1     3       0     0

# %% [markdown]
# Use '&' for "and" and '|' for "or".

# %%
# Display the patients who are 70 over as well as the patients whose trestbps score is greater than 170.
heart[(heart['age'] >= 70) | (heart['trestbps'] >= 170)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 8     52    1   2       172   199    1        1      162      0      0.5
# 25    71    0   1       160   302    0        1      162      0      0.4
# 60    71    0   2       110   265    1        0      130      0      0.0
# 101   59    1   3       178   270    0        0      145      0      4.2
# 110   64    0   0       180   325    0        1      154      1      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 145   70    1   1       156   245    0        0      143      0      0.0
# 151   71    0   0       112   149    0        1      125      0      1.6
# 152   64    1   3       170   227    0        0      155      0      0.6
# 195   59    1   0       170   326    0        0      140      1      3.4
# 203   68    1   2       180   274    1        0      150      1      1.6
# 223   56    0   0       200   288    1        0      133      1      4.0
# 225   70    1   0       145   174    0        1      125      1      2.6
# 228   59    1   3       170   288    0        0      159      0      0.2
# 234   70    1   0       130   322    0        0      109      0      2.4
# 238   77    1   0       125   304    0        0      162      1      0.0
# 240   70    1   2       160   269    0        1      112      1      2.9
# 241   59    0   0       174   249    0        1      143      1      0.0
# 248   54    1   1       192   283    0        0      195      0      0.0
# 260   66    0   0       178   228    1        1      165      1      1.0
# 266   55    0   0       180   327    0        2      117      1      3.4
# 292   58    0   0       170   225    1        0      146      1      2.8
#
#      slope  ca  thal  target  test
# 8        2   0     3       1     0
# 25       2   2     2       1     0
# 60       2   1     2       1     0
# 101      0   0     3       1     0
# 110      2   0     2       1     0
# 129      2   1     2       1     0
# 144      1   0     2       1     0
# 145      2   0     2       1     0
# 151      1   0     2       1     0
# 152      1   0     3       1     0
# 195      0   0     3       0     0
# 203      1   0     3       0     0
# 223      0   2     3       0     0
# 225      0   0     3       0     0
# 228      1   0     3       0     0
# 234      1   3     2       0     0
# 238      2   3     2       0     0
# 240      1   1     3       0     0
# 241      1   0     2       0     0
# 248      2   1     3       0     0
# 260      1   2     3       0     0
# 266      1   0     2       0     0
# 292      1   2     1       0     0

# %% [markdown]
# ## .loc() and .iloc()

# %% [markdown]
# We can use .loc to get, say, the first ten values of the age and trestbps columns:

# %%
heart.loc[:10, ['age', 'trestbps']]
# Out:
#     age  trestbps
# 0    63       145
# 1    37       130
# 2    41       130
# 3    56       120
# 4    57       120
# 5    57       140
# 6    56       140
# 7    44       120
# 8    52       172
# 9    57       150
# 10   54       140

# %% [markdown]
# .iloc() is used for selecting locations in the DataFrame **by number**:

# %%
# How would we get the same slice as just above by using .iloc() instead of .loc()?
heart.iloc[0:11, [0,3]]
# Out:
#     age  trestbps
# 0    63       145
# 1    37       130
# 2    41       130
# 3    56       120
# 4    57       120
# 5    57       140
# 6    56       140
# 7    44       120
# 8    52       172
# 9    57       150
# 10   54       140

# %% [markdown]
# ## Plotting

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Let's plot a histogram of patients' ages:

# %%
plt.hist(heart['age'], bins=40);

# %%
heart[heart['age']<30]
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 72   29    1   1       130   204    0        0      202      0      0.0
#
#     slope  ca  thal  target  test
# 72      2   0     2       1     0

# %% [markdown]
# Let's plot cholesterol vs. age

# %%
chol = heart['chol']
age = heart['age']
xlabel = plt.xlabel("Age")
ylabel = plt.ylabel("Cholesterol")
plt.scatter(age, chol);

# %% [markdown]
# Let's use the target column to color our points:

# %%
xlabel = plt.xlabel("Age")
ylabel = plt.ylabel("Cholesterol")
plt.scatter(age, chol, c=heart['target']);

# %% [markdown]
# ## Let's find a .csv file online and experiment with it.

# %%
#!pwd
banff_pet_data = pd.read_csv('PetLicences.csv')
banff_pet_data.head()
# Out:
#      DOGNAME         DOGTAG         DOGCOLOR  SEX          DOGBREED  \
# 0     STONEY                         GRY/WHT    0    BLUE HEELER CR
# 1         TY                             TAN    0  AM.ESKIMO/COCKER
# 2     TANNER                             TAN    0  POODLE/DACHSHUND
# 3  POOH BEAR                           BROWN    0          SHIH TZU
# 4        Max                                    0               cat
#
#                                             FULLADDR  STATUS  LIC_YEAR
# 0                     135 LYNX ST, BANFF, AB, Canada       2      2004
# 1                   423 MARTEN ST, BANFF, AB, Canada       2      2004
# 2                   423 MARTEN ST, BANFF, AB, Canada       2      2004
# 3                  441 MUSKRAT ST, BANFF, AB, Canada       2      2004
# 4                                                ...       2      2004

# %% [markdown]
# ## Your turn!

# %%
banff_pet_data.dtypes
# Out:
# DOGNAME     object
# DOGTAG      object
# DOGCOLOR    object
# SEX          int64
# DOGBREED    object
# FULLADDR    object
# STATUS       int64
# LIC_YEAR     int64
# dtype: object

# %%
banff_pet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1756 entries, 0 to 1755
# Data columns (total 8 columns):
# DOGNAME     1756 non-null object
# DOGTAG      1756 non-null object
# DOGCOLOR    1756 non-null object
# SEX         1756 non-null int64
# DOGBREED    1756 non-null object
# FULLADDR    1756 non-null object
# STATUS      1756 non-null int64
# LIC_YEAR    1756 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 109.8+ KB

# %% [markdown]
# get_dummies method can convert a column into multiple columns as dummy variables with 0 and 1 values

# %%
banff_pet_data['DOGBREED'].value_counts()
# Out:
# DSH                     51
# LAB                     42
# CDSH                    41
# GOLDEN RETRIEVER        36
# LABRADOR                32
# MIXED                   24
# LAB CROSS               23
# BORDER COLLIE           23
# TABBY                   22
# MIX                     20
# HUSKY                   18
# SHEPHERD CROSS          17
# COCKER SPANIEL          17
# LABRADOODLE             14
# POODLE                  13
# LAB X                   13
# RETRIEVER               13
# GERMAN SHEPHERD         12
# BOXER                   12
# BEAGLE                  12
# DOMESTIC                12
# PUG                     12
# YELLOW LAB              12
# DLH                     11
# BOSTON TERRIER          10
# DOMESTIC SHORT HAIR     10
# CHOCOLATE LAB           10
# BLUE HEELER             10
# CDLH                    10
# NONE GIVEN              10
#                         ..
# GERMAN SHEP MIX          1
# SHIBA-INU                1
# Great Dane               1
# BULLMOSTIF               1
# MINI SCHNEIZER           1
# LABRADOR/COLLIE          1
# SHEP BLUE HEELER MIX     1
# ?                        1
# Sheperd/Rottie X         1
# MEDIUM HAIR              1
# KARELIAH BEAR DOG        1
# BEAGLE/CORGI/HEELER      1
# PIT BULL TERRIER         1
# BOXER/BULLDOG/MASTIF     1
# SHEPHERD COLLIE X        1
# LAB/TERRIER              1
# HUSKY/LAB MIX            1
# SHARPEI X LAB            1
# CHIAHUAHUA MIX           1
# COCKER CROSS             1
# POCKET BEAGLE            1
# CHESAPEAK                1
# ENGLISH POINTER          1
# SHITZU/POODLE CR.        1
# LONGHAIRED CAT           1
# J. RUSS TERRIER          1
# SHEPHERD/HUSKEY X        1
# Lab X                    1
# SHEPHERD                 1
# LAB/BOXER                1
# Name: DOGBREED, Length: 855, dtype: int64
